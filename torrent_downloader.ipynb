# %% [markdown]
# <a href="https://colab.research.google.com/github/amalrxj/3rd-sem-lab/blob/main/torrent_downloader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Torrents To Google Drive Downloader
# *Python app to save content from torrent directly to google drive.*

# %% [markdown]
# ### Step 1: Mount Google Drive
# To stream files we need to get access to write on that drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Step 2: Install libtorrent library
# Libtorrent is a feature complete C++ bittorrent implementation focusing on efficiency and scalability.
# https://www.libtorrent.org/

# %%
# !python -m pip install --upgrade pip setuptools wheel
# !python -m pip install lbry-libtorrent
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.11/dist-packages (24.1.2)
# Collecting pip
#   Downloading pip-25.0.1-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (75.2.0)
# Collecting setuptools
#   Downloading setuptools-78.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting wheel
#   Downloading wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Downloading pip-25.0.1-py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 19.7 MB/s eta 0:00:00
# Downloading setuptools-78.1.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.1 MB/s eta 0:00:00
# Downloading wheel-0.45.1-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 4.3 MB/s eta 0:00:00
# Installing collected packages: wheel, setuptools, pip
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# Successfully installed pip-25.0.1 setuptools-78.1.0 wheel-0.45.1
# Collecting lbry-libtorrent
#   Downloading lbry_libtorrent-1.2.4-py3-none-any.whl.metadata (347 bytes)
# Downloading lbry_libtorrent-1.2.4-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 36.0 MB/s eta 0:00:00
# Installing collected packages: lbry-libtorrent
# Successfully installed lbry-libtorrent-1.2.4

# %% [markdown]
# ### Step 3: Paste the Magnet Link in the input box
# Variable **link** stores the link string.

# %%
link = input("PASTE TORRENT/MAGNET LINK HERE \n") # PASTE TORRENT/MAGNET LINK HERE
# Out:
# PASTE TORRENT/MAGNET LINK HERE
# magnet:?xt=urn:btih:702b4fe468c7aa97b8922dfc6f44fad316d96dfd&dn=www.1TamilMV.esq%20-%20Alappuzha%20Gymkhana%20%282025%29%20Malayalam%20PreDVD%20-%201080p%20-%20x264%20-%20HQ%20Clean%20Audio%20-%20%28AAC%202.0%29%20-%202.5GB.mkv&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.tracker.cl%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Fexplodie.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fexodus.desync.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.ololosh.space%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dump.cl%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker-udp.gbitt.info%3A80%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=udp%3A%2F%2Fisk.richardsw.club%3A6969%2Fannounce&tr=udp%3A%2F%2Fdiscord.heihachi.pw%3A6969%2Fannounce&tr=http%3A%2F%2Fwww.torrentsnipe.info%3A2701%2Fannounce&tr=http%3A%2F%2Ftracker810.xyz%3A11450%2Fannounce&tr=http%3A%2F%2Ftracker.vanitycore.co%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker.sbsub.com%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.moxing.party%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker.lintk.me%3A2710%2Fannounce

# %% [markdown]
# ### Step 4: Download torrent

# %%
import libtorrent as lt
import time
import datetime

ses = lt.session()
ses.listen_on(6881, 6891) #here we are defining the ports on which BitTorrent works
params = {
    'save_path': '/content/drive/My Drive/Torrent/',
    'storage_mode': lt.storage_mode_t(2)}
# params means parameters
# In paras we are defining the location on drive where we want to save the downloaded files
# we also define storage mode, in this case we are using "sparse allocation mode"
# The sparse allocation, sparse files are used, and pieces are downloaded directly to where they belong. This is the recommended (and default) mode.
print(link)

handle = lt.add_magnet_uri(ses, link, params)
ses.start_dht()

begin = time.time()
print(datetime.datetime.now())

print ('Downloading Metadata...')
while (not handle.has_metadata()):
    time.sleep(1)
print ('Got Metadata, Starting Torrent Download...')

print("Starting", handle.name())

while (handle.status().state != lt.torrent_status.seeding):
    s = handle.status()
    state_str = ['queued', 'checking', 'downloading metadata', \
            'downloading', 'finished', 'seeding', 'allocating']
    print ('%.2f%% complete (down: %.1f kb/s up: %.1f kB/s peers: %d) %s ' % \
            (s.progress * 100, s.download_rate / 1000, s.upload_rate / 1000, \
            s.num_peers, state_str[s.state]))
    time.sleep(5)

end = time.time()
print(handle.name(), "COMPLETE")

print("Elapsed Time: ",int((end-begin)//60),"min :", int((end-begin)%60), "sec")

print(datetime.datetime.now())
# Out:
# magnet:?xt=urn:btih:702b4fe468c7aa97b8922dfc6f44fad316d96dfd&dn=www.1TamilMV.esq%20-%20Alappuzha%20Gymkhana%20%282025%29%20Malayalam%20PreDVD%20-%201080p%20-%20x264%20-%20HQ%20Clean%20Audio%20-%20%28AAC%202.0%29%20-%202.5GB.mkv&tr=udp%3A%2F%2Ftracker.opentrackr.org%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.demonii.com%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.tracker.cl%3A1337%2Fannounce&tr=udp%3A%2F%2Fopen.stealth.si%3A80%2Fannounce&tr=udp%3A%2F%2Ftracker.torrent.eu.org%3A451%2Fannounce&tr=udp%3A%2F%2Fexplodie.org%3A6969%2Fannounce&tr=udp%3A%2F%2Fexodus.desync.com%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.ololosh.space%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.dump.cl%3A6969%2Fannounce&tr=udp%3A%2F%2Ftracker.bittor.pw%3A1337%2Fannounce&tr=udp%3A%2F%2Ftracker-udp.gbitt.info%3A80%2Fannounce&tr=udp%3A%2F%2Fopentracker.io%3A6969%2Fannounce&tr=udp%3A%2F%2Fisk.richardsw.club%3A6969%2Fannounce&tr=udp%3A%2F%2Fdiscord.heihachi.pw%3A6969%2Fannounce&tr=http%3A%2F%2Fwww.torrentsnipe.info%3A2701%2Fannounce&tr=http%3A%2F%2Ftracker810.xyz%3A11450%2Fannounce&tr=http%3A%2F%2Ftracker.vanitycore.co%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker.sbsub.com%3A2710%2Fannounce&tr=http%3A%2F%2Ftracker.moxing.party%3A6969%2Fannounce&tr=http%3A%2F%2Ftracker.lintk.me%3A2710%2Fannounce
# 2025-04-14 08:35:42.575812
# Downloading Metadata...
# Got Metadata, Starting Torrent Download...
# Starting www.1TamilMV.esq - Alappuzha Gymkhana (2025) Malayalam PreDVD - 1080p - x264 - HQ Clean Audio - (AAC 2.0) - 2.5GB.mkv
# 0.00% complete (down: 9.1 kb/s up: 2.7 kB/s peers: 29) downloading
# 0.08% complete (down: 348.6 kb/s up: 16.2 kB/s peers: 30) downloading
# 0.13% complete (down: 291.6 kb/s up: 53.5 kB/s peers: 34) downloading
# 0.20% complete (down: 392.0 kb/s up: 59.4 kB/s peers: 27) downloading
# 0.45% complete (down: 1028.3 kb/s up: 88.0 kB/s peers: 40) downloading
# 0.83% complete (down: 1759.6 kb/s up: 101.6 kB/s peers: 50) downloading
# 1.37% complete (down: 2565.2 kb/s up: 111.5 kB/s peers: 58) downloading
# 1.81% complete (down: 2509.0 kb/s up: 97.6 kB/s peers: 62) downloading
# 2.09% complete (down: 1857.0 kb/s up: 111.2 kB/s peers: 70) downloading
# 2.39% complete (down: 1694.9 kb/s up: 107.4 kB/s peers: 73) downloading
# 2.67% complete (down: 1633.6 kb/s up: 95.1 kB/s peers: 84) downloading
# 2.91% complete (down: 1456.3 kb/s up: 84.8 kB/s peers: 95) downloading
# 3.24% complete (down: 1669.2 kb/s up: 91.7 kB/s peers: 99) downloading
# 3.61% complete (down: 1969.9 kb/s up: 101.8 kB/s peers: 100) downloading
# 4.13% complete (down: 2690.9 kb/s up: 121.0 kB/s peers: 108) downloading
# 4.64% complete (down: 2789.1 kb/s up: 120.0 kB/s peers: 122) downloading
# 5.11% complete (down: 2684.6 kb/s up: 118.0 kB/s peers: 124) downloading
# 5.60% complete (down: 2738.4 kb/s up: 115.0 kB/s peers: 122) downloading
# 6.11% complete (down: 2854.4 kb/s up: 118.2 kB/s peers: 132) downloading
# 6.60% complete (down: 2781.6 kb/s up: 119.1 kB/s peers: 134) downloading
# 7.10% complete (down: 2808.9 kb/s up: 114.6 kB/s peers: 136) downloading
# 7.70% complete (down: 3167.0 kb/s up: 135.3 kB/s peers: 137) downloading
# 8.21% complete (down: 2928.7 kb/s up: 141.2 kB/s peers: 134) downloading
# 8.59% complete (down: 2364.6 kb/s up: 121.2 kB/s peers: 128) downloading
# 9.08% complete (down: 2611.4 kb/s up: 131.9 kB/s peers: 131) downloading
# 9.61% complete (down: 2840.2 kb/s up: 127.4 kB/s peers: 131) downloading
# 10.18% complete (down: 3108.9 kb/s up: 138.9 kB/s peers: 136) downloading
# 10.87% complete (down: 3564.1 kb/s up: 151.0 kB/s peers: 138) downloading
# 11.53% complete (down: 3692.0 kb/s up: 157.9 kB/s peers: 140) downloading
# 12.15% complete (down: 3483.3 kb/s up: 145.6 kB/s peers: 139) downloading
# 12.76% complete (down: 3489.8 kb/s up: 144.7 kB/s peers: 141) downloading
# 13.43% complete (down: 3573.0 kb/s up: 150.7 kB/s peers: 139) downloading
# 14.03% complete (down: 3511.9 kb/s up: 141.8 kB/s peers: 139) downloading
# 14.61% complete (down: 3300.2 kb/s up: 130.3 kB/s peers: 135) downloading
# 15.17% complete (down: 3209.9 kb/s up: 134.7 kB/s peers: 131) downloading
# 15.77% complete (down: 3390.2 kb/s up: 146.6 kB/s peers: 137) downloading
# 16.48% complete (down: 3793.2 kb/s up: 154.0 kB/s peers: 136) downloading
# 17.10% complete (down: 3592.5 kb/s up: 147.0 kB/s peers: 137) downloading
# 17.75% complete (down: 3611.6 kb/s up: 146.0 kB/s peers: 140) downloading
# 18.39% complete (down: 3650.1 kb/s up: 142.8 kB/s peers: 141) downloading
# 19.01% complete (down: 3634.2 kb/s up: 144.1 kB/s peers: 138) downloading
# 19.58% complete (down: 3354.6 kb/s up: 133.8 kB/s peers: 137) downloading
# 20.17% complete (down: 3359.7 kb/s up: 138.3 kB/s peers: 143) downloading
# 20.75% complete (down: 3188.5 kb/s up: 132.3 kB/s peers: 142) downloading
# 21.33% complete (down: 3286.3 kb/s up: 136.8 kB/s peers: 150) downloading
# 21.90% complete (down: 3212.2 kb/s up: 131.9 kB/s peers: 149) downloading
# 22.25% complete (down: 2374.6 kb/s up: 125.1 kB/s peers: 149) downloading
# 22.64% complete (down: 2268.7 kb/s up: 127.3 kB/s peers: 150) downloading
# 23.15% complete (down: 2828.7 kb/s up: 143.9 kB/s peers: 153) downloading
# 23.78% complete (down: 3120.6 kb/s up: 148.1 kB/s peers: 153) downloading
# 24.36% complete (down: 3154.4 kb/s up: 145.9 kB/s peers: 152) downloading
# 24.95% complete (down: 3307.3 kb/s up: 149.3 kB/s peers: 160) downloading
# 25.54% complete (down: 3282.0 kb/s up: 142.5 kB/s peers: 154) downloading
# 26.11% complete (down: 3281.9 kb/s up: 140.3 kB/s peers: 155) downloading
# 26.68% complete (down: 3246.2 kb/s up: 136.6 kB/s peers: 157) downloading
# 27.23% complete (down: 3139.3 kb/s up: 134.1 kB/s peers: 154) downloading
# 27.75% complete (down: 3029.0 kb/s up: 132.2 kB/s peers: 163) downloading
# 28.22% complete (down: 2794.4 kb/s up: 123.0 kB/s peers: 157) downloading
# 28.70% complete (down: 2735.8 kb/s up: 125.9 kB/s peers: 156) downloading
# 29.17% complete (down: 2671.7 kb/s up: 131.2 kB/s peers: 154) downloading
# 29.66% complete (down: 2665.2 kb/s up: 126.5 kB/s peers: 153) downloading
# 30.14% complete (down: 2672.8 kb/s up: 132.4 kB/s peers: 155) downloading
# 30.62% complete (down: 2737.0 kb/s up: 137.3 kB/s peers: 153) downloading
# 31.13% complete (down: 2772.7 kb/s up: 140.2 kB/s peers: 152) downloading
# 31.67% complete (down: 2947.0 kb/s up: 149.4 kB/s peers: 159) downloading
# 32.23% complete (down: 3073.7 kb/s up: 144.6 kB/s peers: 159) downloading
# 32.77% complete (down: 3084.1 kb/s up: 134.9 kB/s peers: 168) downloading
# 33.11% complete (down: 2398.2 kb/s up: 117.2 kB/s peers: 170) downloading
# 33.46% complete (down: 2215.4 kb/s up: 119.1 kB/s peers: 167) downloading
# 33.91% complete (down: 2355.9 kb/s up: 120.4 kB/s peers: 161) downloading
# 34.36% complete (down: 2551.5 kb/s up: 123.6 kB/s peers: 163) downloading
# 34.89% complete (down: 2804.5 kb/s up: 130.9 kB/s peers: 161) downloading
# 35.37% complete (down: 2785.1 kb/s up: 133.3 kB/s peers: 154) downloading
# 35.84% complete (down: 2710.5 kb/s up: 134.1 kB/s peers: 149) downloading
# 36.29% complete (down: 2645.3 kb/s up: 131.4 kB/s peers: 152) downloading
# 36.82% complete (down: 2885.4 kb/s up: 141.0 kB/s peers: 150) downloading
# 37.32% complete (down: 2888.9 kb/s up: 136.5 kB/s peers: 152) downloading
# 38.06% complete (down: 3656.1 kb/s up: 161.3 kB/s peers: 153) downloading
# 38.87% complete (down: 4412.0 kb/s up: 192.2 kB/s peers: 158) downloading
# 39.59% complete (down: 4113.1 kb/s up: 178.2 kB/s peers: 159) downloading
# 40.30% complete (down: 4054.8 kb/s up: 176.0 kB/s peers: 162) downloading
# 40.95% complete (down: 3794.6 kb/s up: 165.7 kB/s peers: 167) downloading
# 41.63% complete (down: 3806.6 kb/s up: 165.8 kB/s peers: 165) downloading
# 42.45% complete (down: 4328.4 kb/s up: 187.0 kB/s peers: 162) downloading
# 43.28% complete (down: 4546.9 kb/s up: 191.7 kB/s peers: 156) downloading
# 44.06% complete (down: 4427.5 kb/s up: 187.6 kB/s peers: 167) downloading
# 44.85% complete (down: 4483.1 kb/s up: 188.2 kB/s peers: 164) downloading
# 45.66% complete (down: 4564.3 kb/s up: 192.7 kB/s peers: 163) downloading
# 46.37% complete (down: 4212.0 kb/s up: 179.6 kB/s peers: 166) downloading
# 47.09% complete (down: 4098.5 kb/s up: 174.7 kB/s peers: 163) downloading
# 47.80% complete (down: 4074.3 kb/s up: 175.9 kB/s peers: 162) downloading
# 48.47% complete (down: 3868.2 kb/s up: 168.8 kB/s peers: 166) downloading
# 49.13% complete (down: 3779.2 kb/s up: 161.8 kB/s peers: 159) downloading
# 49.65% complete (down: 3195.4 kb/s up: 147.6 kB/s peers: 162) downloading
# 50.16% complete (down: 2978.6 kb/s up: 144.7 kB/s peers: 158) downloading
# 50.65% complete (down: 2823.8 kb/s up: 141.9 kB/s peers: 157) downloading
# 51.17% complete (down: 2895.0 kb/s up: 139.3 kB/s peers: 158) downloading
# 51.66% complete (down: 2820.4 kb/s up: 137.1 kB/s peers: 158) downloading
# 52.18% complete (down: 2907.8 kb/s up: 138.0 kB/s peers: 159) downloading
# 52.81% complete (down: 3293.0 kb/s up: 141.1 kB/s peers: 166) downloading
# 53.33% complete (down: 3072.7 kb/s up: 138.4 kB/s peers: 165) downloading
# 53.86% complete (down: 3012.8 kb/s up: 140.3 kB/s peers: 169) downloading
# 54.43% complete (down: 3132.5 kb/s up: 139.3 kB/s peers: 166) downloading
# 54.98% complete (down: 3186.8 kb/s up: 137.7 kB/s peers: 165) downloading
# 55.56% complete (down: 3168.3 kb/s up: 137.8 kB/s peers: 166) downloading
# 56.13% complete (down: 3210.7 kb/s up: 139.8 kB/s peers: 170) downloading
# 56.69% complete (down: 3207.4 kb/s up: 143.5 kB/s peers: 174) downloading
# 57.23% complete (down: 3085.7 kb/s up: 134.9 kB/s peers: 165) downloading
# 57.77% complete (down: 3062.5 kb/s up: 135.2 kB/s peers: 161) downloading
# 58.31% complete (down: 3057.3 kb/s up: 131.7 kB/s peers: 164) downloading
# 58.80% complete (down: 2848.2 kb/s up: 129.6 kB/s peers: 164) downloading
# 59.23% complete (down: 2599.0 kb/s up: 126.5 kB/s peers: 164) downloading
# 59.65% complete (down: 2440.2 kb/s up: 128.2 kB/s peers: 163) downloading
# 60.06% complete (down: 2370.9 kb/s up: 130.3 kB/s peers: 165) downloading
# 60.51% complete (down: 2460.0 kb/s up: 127.8 kB/s peers: 163) downloading
# 60.99% complete (down: 2658.8 kb/s up: 131.0 kB/s peers: 171) downloading
# 61.52% complete (down: 2854.6 kb/s up: 129.9 kB/s peers: 170) downloading
# 62.11% complete (down: 3152.5 kb/s up: 139.5 kB/s peers: 167) downloading
# 62.73% complete (down: 3317.4 kb/s up: 149.1 kB/s peers: 165) downloading
# 63.35% complete (down: 3470.5 kb/s up: 149.3 kB/s peers: 168) downloading
# 63.96% complete (down: 3427.0 kb/s up: 143.6 kB/s peers: 166) downloading
# 64.55% complete (down: 3359.5 kb/s up: 142.7 kB/s peers: 161) downloading
# 65.14% complete (down: 3362.7 kb/s up: 148.9 kB/s peers: 168) downloading
# 65.77% complete (down: 3447.2 kb/s up: 160.1 kB/s peers: 162) downloading
# 66.62% complete (down: 4304.2 kb/s up: 186.0 kB/s peers: 165) downloading
# 67.29% complete (down: 4004.9 kb/s up: 175.0 kB/s peers: 161) downloading
# 68.00% complete (down: 3996.6 kb/s up: 173.7 kB/s peers: 156) downloading
# 68.80% complete (down: 4262.8 kb/s up: 181.7 kB/s peers: 157) downloading
# 69.62% complete (down: 4602.9 kb/s up: 190.3 kB/s peers: 161) downloading
# 70.34% complete (down: 4380.5 kb/s up: 176.9 kB/s peers: 153) downloading
# 71.00% complete (down: 3879.6 kb/s up: 160.5 kB/s peers: 151) downloading
# 71.58% complete (down: 3556.1 kb/s up: 149.4 kB/s peers: 159) downloading
# 72.14% complete (down: 3170.6 kb/s up: 133.2 kB/s peers: 159) downloading
# 72.70% complete (down: 3175.7 kb/s up: 141.3 kB/s peers: 163) downloading
# 73.28% complete (down: 3189.5 kb/s up: 143.0 kB/s peers: 171) downloading
# 73.90% complete (down: 3385.2 kb/s up: 146.4 kB/s peers: 165) downloading
# 74.53% complete (down: 3452.0 kb/s up: 148.5 kB/s peers: 170) downloading
# 75.09% complete (down: 3250.8 kb/s up: 142.4 kB/s peers: 169) downloading
# 75.70% complete (down: 3374.6 kb/s up: 144.2 kB/s peers: 171) downloading
# 76.30% complete (down: 3371.4 kb/s up: 144.5 kB/s peers: 166) downloading
# 76.91% complete (down: 3407.5 kb/s up: 145.4 kB/s peers: 166) downloading
# 77.53% complete (down: 3437.2 kb/s up: 144.6 kB/s peers: 167) downloading
# 78.16% complete (down: 3522.6 kb/s up: 145.1 kB/s peers: 168) downloading
# 78.75% complete (down: 3437.7 kb/s up: 150.0 kB/s peers: 167) downloading
# 79.30% complete (down: 3273.0 kb/s up: 145.7 kB/s peers: 179) downloading
# 79.88% complete (down: 3192.3 kb/s up: 143.7 kB/s peers: 181) downloading
# 80.45% complete (down: 3247.6 kb/s up: 148.0 kB/s peers: 173) downloading
# 81.01% complete (down: 3230.2 kb/s up: 141.3 kB/s peers: 179) downloading
# 81.53% complete (down: 3080.9 kb/s up: 133.5 kB/s peers: 181) downloading
# 82.13% complete (down: 3243.4 kb/s up: 137.2 kB/s peers: 177) downloading
# 82.69% complete (down: 3250.9 kb/s up: 143.1 kB/s peers: 182) downloading
# 83.23% complete (down: 3171.9 kb/s up: 138.0 kB/s peers: 182) downloading
# 83.75% complete (down: 2972.6 kb/s up: 134.1 kB/s peers: 180) downloading
# 84.24% complete (down: 2852.8 kb/s up: 133.1 kB/s peers: 176) downloading
# 84.72% complete (down: 2750.6 kb/s up: 128.5 kB/s peers: 175) downloading
# 85.25% complete (down: 2976.7 kb/s up: 136.8 kB/s peers: 172) downloading
# 85.79% complete (down: 2946.8 kb/s up: 133.1 kB/s peers: 173) downloading
# 86.33% complete (down: 3064.4 kb/s up: 133.0 kB/s peers: 175) downloading
# 86.85% complete (down: 2985.6 kb/s up: 131.2 kB/s peers: 180) downloading
# 87.40% complete (down: 3048.6 kb/s up: 129.6 kB/s peers: 175) downloading
# 87.97% complete (down: 3148.8 kb/s up: 134.0 kB/s peers: 179) downloading
# 88.52% complete (down: 3138.7 kb/s up: 133.7 kB/s peers: 177) downloading
# 89.05% complete (down: 3028.3 kb/s up: 130.9 kB/s peers: 174) downloading
# 89.58% complete (down: 2999.6 kb/s up: 131.5 kB/s peers: 171) downloading
# 90.12% complete (down: 3067.3 kb/s up: 135.4 kB/s peers: 172) downloading
# 90.66% complete (down: 3061.1 kb/s up: 136.2 kB/s peers: 171) downloading
# 91.22% complete (down: 3112.9 kb/s up: 137.7 kB/s peers: 168) downloading
# 91.77% complete (down: 3128.8 kb/s up: 135.3 kB/s peers: 168) downloading
# 92.33% complete (down: 3191.0 kb/s up: 137.6 kB/s peers: 170) downloading
# 92.89% complete (down: 3186.1 kb/s up: 135.3 kB/s peers: 167) downloading
# 93.44% complete (down: 3177.3 kb/s up: 150.6 kB/s peers: 175) downloading
# 94.04% complete (down: 3237.0 kb/s up: 148.1 kB/s peers: 178) downloading
# 94.59% complete (down: 3171.7 kb/s up: 137.0 kB/s peers: 178) downloading
# 95.12% complete (down: 3026.2 kb/s up: 129.1 kB/s peers: 172) downloading
# 95.71% complete (down: 3241.6 kb/s up: 134.1 kB/s peers: 172) downloading
# 96.29% complete (down: 3271.7 kb/s up: 134.4 kB/s peers: 167) downloading
# 96.84% complete (down: 3224.1 kb/s up: 131.6 kB/s peers: 171) downloading
# 97.39% complete (down: 3098.7 kb/s up: 143.2 kB/s peers: 173) downloading
# 97.99% complete (down: 3346.9 kb/s up: 159.4 kB/s peers: 173) downloading
# 98.55% complete (down: 3217.0 kb/s up: 153.7 kB/s peers: 182) downloading
# 99.15% complete (down: 3343.8 kb/s up: 155.2 kB/s peers: 182) downloading
# 99.66% complete (down: 3002.3 kb/s up: 142.8 kB/s peers: 181) downloading
# 99.85% complete (down: 1850.3 kb/s up: 130.6 kB/s peers: 178) downloading
# 99.98% complete (down: 1353.4 kb/s up: 121.8 kB/s peers: 176) downloading
# www.1TamilMV.esq - Alappuzha Gymkhana (2025) Malayalam PreDVD - 1080p - x264 - HQ Clean Audio - (AAC 2.0) - 2.5GB.mkv COMPLETE
# Elapsed Time:  15 min : 53 sec
# 2025-04-14 08:51:35.766726
